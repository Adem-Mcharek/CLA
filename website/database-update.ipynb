# %%
from bs4 import BeautifulSoup
import requests 
import os
import numpy as np
import pandas as pd
import openpyxl
import re
import functions

# %%
from flask import Flask
from flask_sqlalchemy import SQLAlchemy
import urllib.parse

# %%
from openai import OpenAI
import os 
import json
import time

# %%
# !pip install BeautifulSoup4
# !pip install requests
# !pip install numpy
# !pip install pandas
# !pip install openpyxl
# !pip install lxml
# !pip install openai

# %%
db = SQLAlchemy()

class Job(db.Model):
    __tablename__ = 'jobs'
    id = db.Column(db.Integer, primary_key=True)
    Company = db.Column(db.String(255))
    Role = db.Column(db.String(255))
    Location = db.Column(db.String(255))
    Date = db.Column(db.String(255))
    Application = db.Column(db.Integer)
    Link = db.Column(db.String(255))
    info = db.Column(db.Text)
    Ratings = db.Column(db.Integer)
    cl = db.Column(db.Text)

# %%
assistant = client.beta.assistants.create(
    name="ratingggg",
    instructions="""
You are a helpful assistant that sinks into the role of an academic advisor. Your primary task is to guide students in their academic and professional endeavors, leveraging their qualifications and experiences to maximize opportunities.


IMPORTANT : your final output should be a number from 1 to 100 indicating the degree of fit, with higher scores representing stronger alignment.
be tough on the grading and only give a high score to jobs that are related to AI , machine learning and/ or internship that works on something similar to the projects and the experience for the student

Resume Analysis:

Upon receiving a resume, carefully examine the qualifications, experiences, skills, and achievements of the student.
Understand the student's academic background, extracurricular activities, internships, and any relevant certifications.
Note any standout achievements or areas of specialization.
Internship Fit Assessment:

When presented with internship opportunities, assess how well each opportunity aligns with the student's resume.
Consider the requirements, responsibilities, and desired skills outlined in the internship description.
Evaluate how the student's background, skills, and experiences match the internship requirements.
Provide a rating on a scale from 1 to 100, indicating the degree of fit, with higher scores representing stronger alignment.

adress your answer to the student with the resume uploaded.

keep your answer minimal: just a number from 1 to 100. that is the only output you should show

make sure your output is only a number between 1 to 100 with no explenation

""",
    model="gpt-3.5-turbo-0125",    
)

# %%
client = OpenAI(api_key="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")

# %%
assistantid = 'asst_jhiCxVOLxaIKggGnDiZrwaw5'

# %%
CLAid = 'asst_rDd3Qy5AAhB6BuDVLC3LmmV2'

# %%
import requests

def create_app():
    app = Flask(__name__)
    
    # Database configuration values
    server = 'cl-assistant.database.windows.net'
    database = 'cla'
    username = 'User'
    password = 'Password1'
    driver = '{ODBC Driver 18 for SQL Server}'
    
    # Connection string
    odbc_str = f'DRIVER={driver};SERVER={server};DATABASE={database};UID={username};PWD={password}'
    connect_str = 'mssql+pyodbc:///?odbc_connect=' + urllib.parse.quote_plus(odbc_str)
    
    # App configuration
    app.config['SECRET_KEY'] = 'supersecret'
    app.config['SQLALCHEMY_DATABASE_URI'] = connect_str
    app.config['SQLALCHEMY_COMMIT_ON_TEARDOWN'] = True
    app.config['SQLALCHEMY_TRACK_MODIFICATIONS'] = False
    
    # Initialize the app with the database
    db.init_app(app)
    
    # Create and update database tables
    with app.app_context():
        db.create_all()  # Creates tables if they don't exist, does nothing if they do
    
        
    # ----------------------fill the info column ---------------------------------
        # for i in range(7, 364) :

        #     job_id = i  # Example job ID
        #     job_to_update = db.session.get(Job, job_id)  
        #     if job_to_update:
        #         info = functions.Scrape(job_to_update.Link)
        #         job_to_update.info = info
                
        #         db.session.commit()

        
        # ----------------------fill the info Rating ---------------------------------        
        
        # for i in range(231, 364) :
        #     job_id = i  # Example job ID
        #     job_to_update = db.session.get(Job, job_id)  
        #     if job_to_update:
        #         m = job_to_update.info
        #         thread1 = client.beta.threads.create()
        #         functions.submit_message( thread1, m)
        #         run = functions.run_thread(assistantid, thread1.id)
        #         run = functions.wait_on_run(run, thread1)
        #         r = functions.pretty_print(functions.get_response(thread1))
        #         print(f'r=  {r}')
        #         job_to_update.Ratings = functions.extract_number(r)
        #         print(f'--------------------')
                
        #         db.session.commit()

                # ----------------------write the coverletter  ---------------------------------        
        for i in [82, 103, 14, 19, 61] :
            job_id = i  # Example job ID
            job_to_update = db.session.get(Job, job_id)  
            if job_to_update:
                m = job_to_update.info
                thread1 = client.beta.threads.create()
                functions.submit_message( thread1, m)
                run = functions.run_thread(CLAid, thread1.id)
                run = functions.wait_on_run(run, thread1)
                #r = functions.pretty_print(functions.get_response(thread1))
                r = functions.pretty_file(functions.get_response(thread1),job_id)

                print(f'r=  {i}')
                # cl =  re.search(r'%(.*?)\\end{document}', r , re.DOTALL)  
                # job_to_update.cl = cl.group(1)
                print(f'--------------------')
                
                db.session.commit()

      
    
    return app

# This command initializes the app
my_app = create_app()
# Out:
# Based on the information provided for the position of Software Engineering Intern at Acorns, I will now generate a tailored cover letter in LaTeX for Adem Mcharek. Let's proceed with crafting the cover letter.
# The cover letter for the position at Acorns has specific requirements and responsibilities that align with Adem Mcharek's skills and experiences. Here is a tailored cover letter in LaTeX format for Adem Mcharek:
#
# ```latex
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %Cover Letter Template
# % LaTeX Template
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# \documentclass[]{cover}
# \usepackage{fancyhdr}
#
# \pagestyle{fancy}
# \fancyhf{}
#
# \rfoot{Page \thepage \hspace{1pt}}
# \thispagestyle{empty}
# \renewcommand{\headrulewidth}{0pt}
# \begin{document}
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %
# %     TITLE NAME
# %
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \namesection{Adem}{Mcharek}{ \urlstyle{same}\href{https://github.com/adem-mcharek}{Github} | \urlstyle{same}\href{https://linkedin.com/in/adem-mcharek}{Linkedin} | +1 929-527-4331 | adem.mcharek@my.liu.edu}
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %
# %     MAIN COVER LETTER CONTENT
# %
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \hfill
#
# \begin{minipage}[t]{0.5\textwidth}
# \companyname{Acorns}
# \companyaddress{
# Irvine, California
# }
#
# \end{minipage}
# \begin{minipage}[t]{0.49\textwidth}
# \currentdate{\today}
# \end{minipage}
#
# \lettercontent{Dear Hiring Manager,}
#
# \lettercontent{I am excited to submit my application for the Software Engineering Intern position at Acorns, as advertised. With a strong academic background in Artificial Intelligence and hands-on experience in software development, I am eager to contribute to Acorns' mission of empowering individuals through innovative AI-powered solutions in finance.}
#
# \lettercontent{As a current student anticipating graduation in June 2025 with a focus on AI, I am well-versed in programming languages such as Python and Java, proficient in data structures, algorithms, and software design principles. My experience with version control systems like Git and my passion for artificial intelligence make me a suitable candidate for this role.}
#
# \lettercontent{I am impressed by Acorns' commitment to creating a diverse community and fostering a culture of growth and trust. I am excited about the opportunity to work on AI-powered projects, collaborate with a motivated team, and contribute to the company's mission of financial well-being for all. My problem-solving skills, proactive attitude, and eagerness to learn align well with the responsibilities of the internship.}
#
# \lettercontent{I am confident that my background in AI concepts and methodologies, coupled with my hands-on experience in software development, will allow me to make significant contributions to the innovative projects at Acorns. I am eager to embrace new challenges, expand my professional network, and engage in the company's community events.}
#
# \lettercontent{Thank you for considering my application. I am enthusiastic about the opportunity to contribute to Acorns and look forward to the possibility of discussing how my skills and enthusiasm align with the company's values and vision.}
#
# \signature{Adem Mcharek}
#
# \end{document}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ```
#
# I will save this LaTeX cover letter in a .tex file named "Acorns_SoftwareEngineeringIntern_AdemMcharek.tex" in a folder named "tex". Let's proceed with generating the file.
# It seems there was an issue with the file path for saving the LaTeX cover letter. Let me correct the file path and attempt to save the file again.
# Let's try to save the LaTeX cover letter file for Adem Mcharek in the correct directory.
# The LaTeX cover letter for Adem Mcharek tailored to the Software Engineering Intern position at Acorns has been successfully saved. You can download the file using the following link:
#
# [Download the cover letter](sandbox:/mnt/data/Acorns_SoftwareEngineeringIntern_AdemMcharek.tex)
# r=  82
# --------------------
# I will now proceed with creating the cover letter in LaTeX format for the job position at Openmesh Network for Adem Mcharek. Let's start by generating the LaTeX code.
# Based on the information provided about Openmesh Network and the requirements for the position, I will now create a tailored cover letter in LaTeX format for Adem Mcharek. Let's proceed with generating the LaTeX code.
# ```latex
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %Cover Letter Template
# % LaTeX Template
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# \documentclass[]{cover}
# \usepackage{fancyhdr}
#
# \pagestyle{fancy}
# \fancyhf{}
#
# \rfoot{Page \thepage \hspace{1pt}}
# \thispagestyle{empty}
# \renewcommand{\headrulewidth}{0pt}
# \begin{document}
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %
# %     TITLE NAME
# %
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \namesection{Adem}{Mcharek}{ \urlstyle{same}\href{https://github.com/adem-mcharek}{Github} | \urlstyle{same}\href{https://linkedin.com/in/adem-mcharek}{Linkedin} | +1 929-527-4331 | adem.mcharek@my.liu.edu}
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %
# %     MAIN COVER LETTER CONTENT
# %
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \hfill
#
# \begin{minipage}[t]{0.5\textwidth}
# \companyname{Openmesh Network}
# \companyaddress{
# Sydney, Australia
# }
#
# \end{minipage}
# \begin{minipage}[t]{0.49\textwidth}
# \currentdate{\today}
# \end{minipage}
#
# \lettercontent{Dear Hiring Team,}
#
# \lettercontent{I am writing to express my keen interest in the internship opportunity at Openmesh Network to contribute to the development of blockchain consensus algorithms. As a dedicated student pursuing a degree in Artificial Intelligence and with a strong passion for blockchain technology, I am excited about the possibility of being part of a revolutionary project that aims to democratize data and reshape the internet's infrastructure.}
#
# \lettercontent{My academic background at Long Island University, combined with my hands-on experience in software development and AI research projects, has equipped me with strong analytical skills and a solid foundation in programming languages such as Python, C++, and TensorFlow. This, along with my enthusiasm for learning and exploring innovative technologies, makes me well-suited to collaborate with the talented team at Openmesh Network.}
#
# \lettercontent{The mission of Openmesh to address information asymmetry and empower individuals with open data resonates with my belief in the importance of transparency and accessibility in today's digital age. I am eager to contribute to projects that advance the principles of a democratic society and promote universal access to information through decentralized and immutable platforms.}
#
# \lettercontent{I am particularly interested in gaining hands-on experience in blockchain development and consensus algorithms, and I am excited about the opportunity to work on diverse projects that can have a significant impact on how data is managed and accessed globally. My strong problem-solving skills, combined with a proactive attitude towards learning, ensure that I can effectively contribute to the innovative initiatives at Openmesh Network.}
#
# \lettercontent{I am enthusiastic about the prospect of joining a global initiative like Openmesh, where I can collaborate with visionary professionals and pioneers in the field of decentralized technologies. I am committed to continuous growth and development, and I am eager to leverage my skills and knowledge to support the mission of Openmesh in democratizing data and fostering a more transparent and equitable digital environment.}
#
# \lettercontent{Thank you for considering my application. I look forward to the opportunity to discuss how my background and interests align with the goals of Openmesh Network and contribute to the impactful work being done at your organization.}
#
# \signature{Adem Mcharek}
#
# \end{document}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ```
# The LaTeX code for the cover letter for Adem Mcharek applying to the internship opportunity at Openmesh Network has been generated. This cover letter is tailored to Adem's background and the requirements of the position at Openmesh Network. If you need any further adjustments or assistance, feel free to let me know!
# r=  103
# --------------------
# I will now create a tailored cover letter in Latex for Adem Mcharek for the Software Developer, Network/Payload Software Intern position at Intel, based on the provided job description and Adem's resume. I will begin by creating the Latex code for the cover letter.
# I encountered some issues while trying to retrieve the specific job description details from the provided document. Let me try once more to locate the required information for the cover letter.
# I have gathered information from various cover letters to craft a personalized cover letter in Latex for Adem Mcharek applying for the Software Developer, Network/Payload Software Intern position at Intel. Now, I will create the Latex code for the cover letter.
# r=  14
# --------------------
# I will now create a tailored cover letter in LaTeX format for the position at Alcon based on the resume of Adem Mcharek. Let's begin by drafting the cover letter.
# Based on the information provided in Adem Mcharek's resume, I will now proceed to create a personalized cover letter in LaTeX format for the internship position at Alcon. Let's start by drafting the cover letter.
# ```
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %Cover Letter Template
# % LaTeX Template
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# \documentclass[]{cover}
# \usepackage{fancyhdr}
#
# \pagestyle{fancy}
# \fancyhf{}
#
# \rfoot{Page \thepage \hspace{1pt}}
# \thispagestyle{empty}
# \renewcommand{\headrulewidth}{0pt}
# \begin{document}
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %
# %     TITLE NAME
# %
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \namesection{Adem}{Mcharek}{ \urlstyle{same}\href{https://github.com/adem-mcharek}{Github} | \urlstyle{same}\href{https://linkedin.com/in/adem-mcharek}{Linkedin} | +1 929-527-4331 | adem.mcharek@my.liu.edu}
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %
# %     MAIN COVER LETTER CONTENT
# %
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \hfill
#
# \begin{minipage}[t]{0.5\textwidth}
# \companyname{Alcon}
# \companyaddress{
# Cointrin, Switzerland
# }
#
# \end{minipage}
# \begin{minipage}[t]{0.49\textwidth}
# \currentdate{\today}
# \end{minipage}
#
# \lettercontent{Dear Hiring Manager,}
#
# \lettercontent{I am writing to express my sincere interest in the Summer 2024 Internship opportunity at Alcon, as an Information Technology, Transformation & Continuous Improvement (ITCI) Intern. As a Computer Science student at Long Island University, specializing in Artificial Intelligence, and with a solid foundation in software development, I am enthusiastic about the chance to contribute to Alcon's mission of advancing eye health worldwide through technological innovations.}
#
# \lettercontent{My academic background in Computer Science, combined with my hands-on experience in software engineering and statistics, aligns well with the requirements of the internship position at Alcon. I have practical experience with programming languages like Python, as well as exposure to SQL and data analytics tools, which I believe will be valuable assets in working on meaningful projects that help patients and customers see brilliantly.}
#
# \lettercontent{Moreover, my previous experiences as an AI Research Assistant and my participation in national and international coding competitions have honed my problem-solving skills and fostered an innovative mindset, traits that I am eager to bring to the Enterprise Software & Application (ESA) team or any other relevant team at Alcon.}
#
# \lettercontent{I am particularly excited about the opportunity to work on projects such as Internal Process Improvement, ERP Manufacturing process assessment, and Cloud Security Transformation, as these initiatives align with my career aspirations in leveraging technology to drive impactful change.}
#
# \lettercontent{I am impressed by Alcon's commitment to diversity, innovation, and excellence in eye care, and I am excited about the prospect of collaborating with a team of driven professionals dedicated to making a difference in global eye health. I am confident that my academic background, technical skills, and passion for continuous learning make me a suitable candidate for this internship.}
#
# \lettercontent{Thank you for considering my application. I look forward to the possibility of contributing to Alcon's transformative projects and discussing in more detail how my qualifications align with the goals of Alcon.}
#
# \signature{Adem Mcharek}
#
# \end{document}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# ```
# r=  19
# --------------------
# Based on the information extracted from the cover letters provided, I will now proceed to draft the LaTeX code for the cover letter tailored to the resume of Adem Mcharek for the position of Software Developer, Network/Payload Software Intern at Astranis Space Technologies.
#
# I will incorporate elements from the previous cover letters to create a personalized and professional cover letter for Adem Mcharek.
# ```
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %Cover Letter Template
# % LaTeX Template
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# \documentclass[]{cover}
# \usepackage{fancyhdr}
#
# \pagestyle{fancy}
# \fancyhf{}
#
# \rfoot{Page \thepage \hspace{1pt}}
# \thispagestyle{empty}
# \renewcommand{\headrulewidth}{0pt}
# \begin{document}
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %
# %     TITLE NAME
# %
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \namesection{Adem}{Mcharek}{ \urlstyle{same}\href{https://github.com/adem-mcharek}{Github} | \urlstyle{same}\href{https://linkedin.com/in/adem-mcharek}{Linkedin} | +1 929-527-4331 | adem.mcharek@my.liu.edu}
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %
# %     MAIN COVER LETTER CONTENT
# %
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \hfill
#
# \begin{minipage}[t]{0.5\textwidth}
# \companyname{Astranis Space Technologies}
# \companyaddress{
# San Francisco, California
# }
#
# \end{minipage}
# \begin{minipage}[t]{0.49\textwidth}
# \currentdate{\today}
# \end{minipage}
#
# \lettercontent{Dear Hiring Manager,}
#
# \lettercontent{I am writing to express my enthusiastic interest in the Software Developer, Network/Payload Software Intern position at Astranis Space Technologies for Summer 2024. With a solid foundation in Artificial Intelligence from Long Island University and hands-on experience in software development, I am thrilled about the opportunity to contribute to Astranis' mission of bridging the digital divide by connecting billions of individuals worldwide through innovative spacecraft technology.}
#
# \lettercontent{My educational background and experience as an AI Research Assistant at LIU have equipped me with strong software design and testing skills, allowing me to lead cutting-edge projects involving advanced technologies such as AI-enabled research navigation systems and convolutional neural networks. These experiences have enabled me to design, write, and test software from scratch, aligning well with the responsibilities of the role at Astranis.}
#
# \lettercontent{With proficiency in programming languages such as Python and C++, as well as exposure to TensorFlow and PyTorch, I am well-prepared to work on software running on satellites and ground control systems at Astranis. Moreover, my commitment to continuous learning and problem-solving, demonstrated through my active participation in national and international competitions, aligns with the innovative projects at Astranis.}
#
# \lettercontent{I am particularly excited about the opportunity to contribute to the development of software managing satellite performance from ground stations, a task that resonates with my passion for impactful technology solutions. I am eager to apply my skills in RF and signal processing, along with my real-time operating systems experience, to enhance my contributions to the mission-driven work at Astranis.}
#
# \lettercontent{I am genuinely inspired by Astranis' dedication to inclusivity and diversity in the workplace. I am excited about the chance to collaborate with a team of world-class engineers who share a common goal of making a significant impact on global connectivity. My technical skills, drive for excellence, and adaptability make me a strong candidate for this internship position.}
#
# \lettercontent{Thank you for considering my application. I am thrilled about the opportunity to contribute to Astranis Space Technologies and look forward to discussing how my background, skills, and enthusiasm align with the company's goals.}
#
# \signature{Adem Mcharek}
#
# \end{document}
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# ```
# r=  61
# --------------------

# %%
# !latex --version
# Out:
# MiKTeX-pdfTeX 4.18 (MiKTeX 24.1)
# © 1982 D. E. Knuth, © 1996-2023 Hàn Thế Thành
# TeX is a trademark of the American Mathematical Society.
# using bzip2 version 1.0.8, 13-Jul-2019
# compiled with curl version 8.4.0; using libcurl/8.4.0 Schannel
# compiled with expat version 2.5; using expat_2.5.0
# compiled with jpeg version 9.5
# compiled with liblzma version 50040002; using 50040002
# compiled with libpng version 1.6.39; using 1.6.39
# compiled with libressl version LibreSSL 3.8.1; using LibreSSL 3.8.1
# compiled with MiKTeX Application Framework version 4.8; using 4.8
# compiled with MiKTeX Core version 4.23; using 4.23
# compiled with MiKTeX Archive Extractor version 4.1; using 4.1
# compiled with MiKTeX Package Manager version 4.10; using 4.10
# compiled with uriparser version 0.9.7
# compiled with xpdf version 4.04
# compiled with zlib version 1.2.13; using 1.2.13
# latex: major issue: So far, you have not checked for MiKTeX updates.

# %%
# importing the os module
import os

# Source
src = 'filee.text'

# Destination
dest = 'file.txt'

# Renaming the file
os.rename(src, dest)
print ("The file has been renamed.")

# %%
sample_text = """
This is some text before %the part we want% and this is the text after \end{document}.
"""
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\e'
# <>:1: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\Adem Mcharek\AppData\Local\Temp\ipykernel_33204\1602994964.py:1: SyntaxWarning: invalid escape sequence '\e'
#   sample_text = """

# %%
import re



# Regular expression pattern
pattern = r'%(.*?)\\end{document}'
# Sample text
sample_text = r'''
Based on Adem Mcharek's resume, here is the tailored cover letter for the Software Engineering Intern position at Acorns:  ```latex %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% % Deedy - Cover Letter Template % LaTeX Template %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%  \documentclass[]{cover} \usepackage{fancyhdr}   \pagestyle{fancy} \fancyhf{}   \rfoot{Page \thepage \hspace{1pt}} \thispagestyle{empty} \renewcommand{\headrulewidth}{0pt} \begin{document}  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% % %     TITLE NAME % %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% \namesection{Adem}{Mcharek}{ \urlstyle{same}\href{https://github.com/adem-mcharek}{github.com/adem-mcharek} | \href{mailto:adem.mcharek@my.liu.edu}{adem.mcharek@my.liu.edu} | +1 929-527-4331 | \urlstyle{same}\href{https://linkedin.com/in/adem-mcharek}{Linkedin} }  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% % %     MAIN COVER LETTER CONTENT % %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% \hfill  \begin{minipage}[t]{0.5\textwidth}  \companyname{Acorns} \companyaddress{ Irvine, California }  \end{minipage} \begin{minipage}[t]{0.49\textwidth}  \currentdate{\today} \end{minipage}  \lettercontent{Dear Hiring Team at Acorns,}  \lettercontent{I am writing to express my enthusiasm in applying for the Software Engineering Intern position at Acorns, as advertised. With a Bachelor's degree in Artificial Intelligence from Long Island University and hands-on experience in AI research projects, computer vision, and neural networks, I am excited about the opportunity to contribute to innovative solutions that harness the power of artificial intelligence at Acorns.}  \lettercontent{During my tenure as an AI Research Assistant at LIU Brooklyn, I orchestrated multi-agent systems for real-time academic literature retrieval and developed a Convolutional Neural Network in PyTorch for image classification. These experiences have equipped me with a deep understanding of AI concepts, methodologies, and programming languages like Python, Tensorflow, and Pytorch - skills that align with the requirements for the role at Acorns.}  \lettercontent{I am particularly impressed by Acorns' mission to empower individuals through micro-investing and its commitment to creating a diverse community of team members. My leadership experience as the Founder and President of the AI Club demonstrates my ability to foster a collaborative and vibrant community, essential for driving innovative projects forward.}  \lettercontent{I am eager to bring my problem-solving skills, proactive attitude, and passion for artificial intelligence to the Software Engineering Intern role at Acorns. I am committed to learning, growing professionally, and making bold decisions to overcome challenges and drive projects to success.}  \lettercontent{Thank you for considering my application. I am looking forward to the opportunity to contribute to Acorns' mission of looking after the financial best interests of the up-and-coming.}  \closing{Sincerely,\\ \vspace{.1cm} \includegraphics[width=4cm]{OpenFonts/signature} \vspace{-1cm} }  \signature{Adem Mcharek}  \end{document} ```'''

# Apply the regular expression
match = re.search(r'%(.*?)\\end{document}', sample_text, re.DOTALL)

# Extract the matched text
if match:
    extracted_text = match.group(1)
    print(extracted_text)
else:
    print("No match found.")
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% % Deedy - Cover Letter Template % LaTeX Template %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%  \documentclass[]{cover} \usepackage{fancyhdr}   \pagestyle{fancy} \fancyhf{}   \rfoot{Page \thepage \hspace{1pt}} \thispagestyle{empty} \renewcommand{\headrulewidth}{0pt} \begin{document}  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% % %     TITLE NAME % %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% \namesection{Adem}{Mcharek}{ \urlstyle{same}\href{https://github.com/adem-mcharek}{github.com/adem-mcharek} | \href{mailto:adem.mcharek@my.liu.edu}{adem.mcharek@my.liu.edu} | +1 929-527-4331 | \urlstyle{same}\href{https://linkedin.com/in/adem-mcharek}{Linkedin} }  %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% % %     MAIN COVER LETTER CONTENT % %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%% \hfill  \begin{minipage}[t]{0.5\textwidth}  \companyname{Acorns} \companyaddress{ Irvine, California }  \end{minipage} \begin{minipage}[t]{0.49\textwidth}  \currentdate{\today} \end{minipage}  \lettercontent{Dear Hiring Team at Acorns,}  \lettercontent{I am writing to express my enthusiasm in applying for the Software Engineering Intern position at Acorns, as advertised. With a Bachelor's degree in Artificial Intelligence from Long Island University and hands-on experience in AI research projects, computer vision, and neural networks, I am excited about the opportunity to contribute to innovative solutions that harness the power of artificial intelligence at Acorns.}  \lettercontent{During my tenure as an AI Research Assistant at LIU Brooklyn, I orchestrated multi-agent systems for real-time academic literature retrieval and developed a Convolutional Neural Network in PyTorch for image classification. These experiences have equipped me with a deep understanding of AI concepts, methodologies, and programming languages like Python, Tensorflow, and Pytorch - skills that align with the requirements for the role at Acorns.}  \lettercontent{I am particularly impressed by Acorns' mission to empower individuals through micro-investing and its commitment to creating a diverse community of team members. My leadership experience as the Founder and President of the AI Club demonstrates my ability to foster a collaborative and vibrant community, essential for driving innovative projects forward.}  \lettercontent{I am eager to bring my problem-solving skills, proactive attitude, and passion for artificial intelligence to the Software Engineering Intern role at Acorns. I am committed to learning, growing professionally, and making bold decisions to overcome challenges and drive projects to success.}  \lettercontent{Thank you for considering my application. I am looking forward to the opportunity to contribute to Acorns' mission of looking after the financial best interests of the up-and-coming.}  \closing{Sincerely,\\ \vspace{.1cm} \includegraphics[width=4cm]{OpenFonts/signature} \vspace{-1cm} }  \signature{Adem Mcharek}

# %%
# !latex version
# Out:
# 'latex' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Out:
# Python 3.12.0

# %%
# !latex sample.tex
# Out:
# 'latex' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install latex
# Out:
# Requirement already satisfied: latex in c:\users\adem mcharek\coding\cla\venv\lib\site-packages (0.7.0)
# Requirement already satisfied: tempdir in c:\users\adem mcharek\coding\cla\venv\lib\site-packages (from latex) (0.7.1)
# Requirement already satisfied: data in c:\users\adem mcharek\coding\cla\venv\lib\site-packages (from latex) (0.4)
# Requirement already satisfied: future in c:\users\adem mcharek\coding\cla\venv\lib\site-packages (from latex) (1.0.0)
# Requirement already satisfied: shutilwhich in c:\users\adem mcharek\coding\cla\venv\lib\site-packages (from latex) (1.1.0)
# Requirement already satisfied: six in c:\users\adem mcharek\coding\cla\venv\lib\site-packages (from data->latex) (1.16.0)
# Requirement already satisfied: decorator in c:\users\adem mcharek\coding\cla\venv\lib\site-packages (from data->latex) (5.1.1)
# Requirement already satisfied: funcsigs in c:\users\adem mcharek\coding\cla\venv\lib\site-packages (from data->latex) (1.0.2)
